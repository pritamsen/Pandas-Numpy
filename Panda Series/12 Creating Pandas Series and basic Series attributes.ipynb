# %% [markdown]
# Let's import the Pandas library

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Let's create an empty Pandas Series

# %%
empty_series = pd.Series()
empty_series

# %%
type(empty_series)

# %%
empty_series.dtype

# %%
empty_series.ndim

# %%
empty_series.shape

# %%
empty_series.size

# %%
empty_series.index  # get index of Series as a RangeIndex object

# %%
empty_series.values  # get values stored in Series as a NumPy array

# %%
# The default name of a series is None, the '0' you see at the top of the series is just a visual artifact which cannot be accessed
empty_series.name

# %%
type(empty_series.name)

# %% [markdown]
# Let's create a Series with elements

# %%
my_series = pd.Series(data = [1, 2, 3, 4])
my_series

# %%
type(my_series)

# %%
my_series.dtype

# %%
my_series.ndim

# %%
my_series.shape

# %%
my_series.size

# %%
my_series.index

# %%
my_series.values

# %%
mixed_series = pd.Series([1, True, 'yes', 3.14, [42, 0]])
mixed_series

# %%
mixed_series.dtype

# %% [markdown]
# We can create a Series with a custom index and name

# %%
named_series = pd.Series(data = ['Ashok', 'Kumar', 18, 183], index = ['Forename', 'Surname', 'Age', 'Height'], name = 'Student Info')
named_series

# %%
named_series['Forename']

# %%
named_series.dtype

# %%
named_series.ndim

# %%
named_series.shape

# %%
named_series.size

# %%
named_series.index

# %%
named_series.values

# %%
named_series.name

# %%
# pd.Series(data = [1, 2, 3], index = ['A', 'B', 'C', 'D'])  # the length of the data and index should match

# %% [markdown]
# We can create Series from other data structures

# %%
my_list = [1, 2, 3, 4]
pd.Series(my_list)

# %%
my_tuple = (1, 2, 3, 4)
pd.Series(my_tuple)

# %%
# my_set = {1, 2, 3, 4}
# pd.Series(my_set)  # sets are unordered and cannot be used to make a Series

# %%
my_dict = {'A': 1, 'B': 2, 'C': 3, 'D': 4}
pd.Series(my_dict)

# %% [markdown]
# Pandas Series are strictly one dimensional

# %%
pd.Series([[1, 2], [3, 4], [5, 6]])

# %%
# import numpy as np
# pd.Series(np.array([[1, 2], [3, 4], [5, 6]]))
